# %%
import os
from collections import defaultdict
import pandas as pd
import geopandas as gpd
import json
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from tqdm import tqdm
import string

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data_dir = "../../data/"
os.listdir(data_dir)
# Out:
# ['bus_stops_wszone.dbf',
#  'bus_stops_wszone.shp',
#  'net_202001_weekday_G.net',
#  'singstat',
#  'net_202001_weekend_G.net',
#  'origin_destination_bus_202001_scaleddown.csv.xz',
#  'net_202001_weekendb.net',
#  'OD_bus',
#  'net_202001_weekdayb.net',
#  'train_station_wszone.prj',
#  'origin_destination_train_202001.csv.xz',
#  'train_station_wszone.dbf',
#  'OD_202001_weekend.csv.xz',
#  'subzone_centroid.csv',
#  'transport_node_bus_202001.csv',
#  'train_station_wszone.cpg',
#  'OD_PT',
#  'train_station_wszone.shx',
#  'planning-area-2014',
#  'subzone_centroid_pos.json',
#  '.ipynb_checkpoints',
#  'origin_destination_bus_202001.csv.xz',
#  'region-2014',
#  'train_station_wszone.shp',
#  'OD_train',
#  'bus_stops_wszone.shx',
#  'OD_202001_weekday.csv.xz',
#  'bus_stops_wszone.prj',
#  'subzone-2014',
#  'bus_stops_wszone.cpg']

# %%
region = gpd.read_file(data_dir+"region-2014/MP14_REGION_WEB_PL.shp")
parea = gpd.read_file(data_dir+"planning-area-2014/MP14_PLNG_AREA_WEB_PL.shp")

# %%
subzone_fp = os.path.join(data_dir, "subzone-2014", "MP14_SUBZONE_WEB_PL.shp")
subzone = gpd.read_file(subzone_fp)
subzone.head()
# Out:
#    OBJECTID  SUBZONE_NO       SUBZONE_N SUBZONE_C CA_IND       PLN_AREA_N  \
# 0         1           1    MARINA SOUTH    MSSZ01      Y     MARINA SOUTH
# 1         2           1    PEARL'S HILL    OTSZ01      Y           OUTRAM
# 2         3           3       BOAT QUAY    SRSZ03      Y  SINGAPORE RIVER
# 3         4           8  HENDERSON HILL    BMSZ08      N      BUKIT MERAH
# 4         5           3         REDHILL    BMSZ03      N      BUKIT MERAH
#
#   PLN_AREA_C        REGION_N REGION_C           INC_CRC  FMEL_UPD_D  \
# 0         MS  CENTRAL REGION       CR  5ED7EB253F99252E  2014-12-05
# 1         OT  CENTRAL REGION       CR  8C7149B9EB32EEFC  2014-12-05
# 2         SR  CENTRAL REGION       CR  C35FEFF02B13E0E5  2014-12-05
# 3         BM  CENTRAL REGION       CR  3775D82C5DDBEFBD  2014-12-05
# 4         BM  CENTRAL REGION       CR  85D9ABEF0A40678F  2014-12-05
#
#        X_ADDR      Y_ADDR   SHAPE_Leng    SHAPE_Area  \
# 0  31595.8357  29220.1873  5267.381024  1.630379e+06
# ...

# %%
sr_weekday = pd.read_csv("Super_SR_lvl_weekday.csv", index_col=0)
sr_weekend = pd.read_csv("Super_SR_lvl_weekend.csv", index_col=0)

# %%
sr_weekday.head()
# Out:
#                   node  lvl_dc_spreader  lvl_hh  lvl_pr_spreader  \
# ind
# 0        TAMPINES EAST                2       2                2
# 1    SERANGOON CENTRAL                3       3                3
# 2          BEDOK NORTH                3       3                3
# 3         GEYLANG EAST                3       3                3
# 4    TOA PAYOH CENTRAL                2       2                2
#
#      lvl_dc_receiver  lvl_ha  lvl_pr_receiver
# ind
# 0                  2       2                2
# 1                  3       3                3
# 2                  3       3                3
# 3                  3       3                3
# 4                  1       2                1

# %%
subzone2 = subzone.merge(sr_weekday, left_on="SUBZONE_N", right_on="node")
print(len(subzone2))
subzone2.head()
# Out:
# 303
#    OBJECTID  SUBZONE_NO       SUBZONE_N SUBZONE_C CA_IND       PLN_AREA_N  \
# 0         1           1    MARINA SOUTH    MSSZ01      Y     MARINA SOUTH
# 1         2           1    PEARL'S HILL    OTSZ01      Y           OUTRAM
# 2         3           3       BOAT QUAY    SRSZ03      Y  SINGAPORE RIVER
# 3         4           8  HENDERSON HILL    BMSZ08      N      BUKIT MERAH
# 4         5           3         REDHILL    BMSZ03      N      BUKIT MERAH
#
#   PLN_AREA_C        REGION_N REGION_C           INC_CRC  ...   SHAPE_Leng  \
# 0         MS  CENTRAL REGION       CR  5ED7EB253F99252E  ...  5267.381024
# 1         OT  CENTRAL REGION       CR  8C7149B9EB32EEFC  ...  3506.107376
# 2         SR  CENTRAL REGION       CR  C35FEFF02B13E0E5  ...  1740.925766
# 3         BM  CENTRAL REGION       CR  3775D82C5DDBEFBD  ...  3313.624904
# 4         BM  CENTRAL REGION       CR  85D9ABEF0A40678F  ...  2825.594099
#
#      SHAPE_Area                                           geometry  \
# ...

# %%
subzone3 = subzone.merge(sr_weekend, left_on="SUBZONE_N", right_on="node")
print(len(subzone3))
subzone3.head()
# Out:
# 303
#    OBJECTID  SUBZONE_NO       SUBZONE_N SUBZONE_C CA_IND       PLN_AREA_N  \
# 0         1           1    MARINA SOUTH    MSSZ01      Y     MARINA SOUTH
# 1         2           1    PEARL'S HILL    OTSZ01      Y           OUTRAM
# 2         3           3       BOAT QUAY    SRSZ03      Y  SINGAPORE RIVER
# 3         4           8  HENDERSON HILL    BMSZ08      N      BUKIT MERAH
# 4         5           3         REDHILL    BMSZ03      N      BUKIT MERAH
#
#   PLN_AREA_C        REGION_N REGION_C           INC_CRC  ...   SHAPE_Leng  \
# 0         MS  CENTRAL REGION       CR  5ED7EB253F99252E  ...  5267.381024
# 1         OT  CENTRAL REGION       CR  8C7149B9EB32EEFC  ...  3506.107376
# 2         SR  CENTRAL REGION       CR  C35FEFF02B13E0E5  ...  1740.925766
# 3         BM  CENTRAL REGION       CR  3775D82C5DDBEFBD  ...  3313.624904
# 4         BM  CENTRAL REGION       CR  85D9ABEF0A40678F  ...  2825.594099
#
#      SHAPE_Area                                           geometry  \
# ...

# %%
with open(os.path.join("../../data", 'subzone_centroid_pos.json'), 'r') as fread:
    pos = json.load(fread)
pos["MARINA SOUTH"]
# Out:
# [31595.83574613999, 29220.18737674884]

# %%
def get_pos(nodes, pos):
    xs = []
    ys = []
    for n in nodes:
        x,y = pos[n]
        xs.append(x)
        ys.append(y)
    return xs, ys

# %%
union_geom = gpd.GeoSeries(subzone2.geometry.unary_union)
union_geom.plot()

# %%
fig, axs = plt.subplots(2,1, figsize=(18,15))


for ax in axs:
    subzone2.plot(color="grey", edgecolor="k", alpha=0.1, ax=ax)
    #region.plot(color="none", edgecolor="k", alpha=0.8, ax=ax)

colors = ["xkcd:scarlet", "xkcd:light rose", "xkcd:soft purple"]

temp1 = subzone2[subzone2["lvl_dc_spreader"]==1]
temp1 = temp1[temp1["lvl_dc_receiver"]==1]
temp1.plot(ax=axs[0], fc=colors[0], ec="w", alpha=.7)
textsa1 = ""
idtext = list("abcdefghijk")
ns = sorted(temp1["node"].tolist())
xx, yy = get_pos(ns, pos)
for i, txt in enumerate(idtext):
    axs[0].annotate(txt, (xx[i], yy[i]), fontsize=15, fontweight="bold", ha="center", va="center")
    textsa1+="{}) {} \n".format(txt, string.capwords(ns[i]))

temp3 = subzone2[subzone2["lvl_dc_spreader"]==1]
temp3 = temp3[temp3["lvl_dc_receiver"]!=1]
temp3.plot(ax=axs[0], fc=colors[2], ec="k", lw=1)
textsc1 = ""
idtext = list("l")
ns = sorted(temp3["node"].tolist())
xx, yy = get_pos(ns, pos)
for i, txt in enumerate(idtext):
    axs[0].annotate(txt, (xx[i], yy[i]), fontsize=15, fontweight="bold", ha="center", va="center")
    textsc1+="{}) {} \n".format(txt, string.capwords(ns[i]))

temp2 = subzone2[subzone2["lvl_dc_receiver"]==1]
temp2 = temp2[temp2["lvl_dc_spreader"]!=1]
temp2.plot(ax=axs[0], fc=colors[1], ec="k", lw=1)
textsb1 = ""
idtext = list("mnop")
ns = sorted(temp2["node"].tolist())
xx, yy = get_pos(ns, pos)
for i, txt in enumerate(idtext):
    axs[0].annotate(txt, (xx[i], yy[i]), fontsize=15, fontweight="bold", ha="center", va="center")
    textsb1+="{}) {} \n".format(txt, string.capwords(ns[i]))



temp1 = subzone3[subzone3["lvl_dc_spreader"]==1]
temp1 = temp1[temp1["lvl_dc_receiver"]==1]
temp1.plot(ax=axs[1], fc=colors[0], ec="w", alpha=.7)
textsa2 = ""
idtext = list("abcdefghijklmn")
ns = sorted(temp1["node"].tolist())
xx, yy = get_pos(ns, pos)
for i, txt in enumerate(idtext):
    axs[1].annotate(txt, (xx[i], yy[i]), fontsize=15, fontweight="bold", ha="center", va="center")
    textsa2+="{}) {} \n".format(txt, string.capwords(ns[i]))

temp3 = subzone3[subzone3["lvl_dc_spreader"]==1]
temp3 = temp3[temp3["lvl_dc_receiver"]!=1]
temp3.plot(ax=axs[1], fc=colors[2], ec="k", lw=1)
textsc2 = ""
idtext = list("o")
ns = sorted(temp3["node"].tolist())
xx, yy = get_pos(ns, pos)
for i, txt in enumerate(idtext):
    axs[1].annotate(txt, (xx[i], yy[i]), fontsize=15, fontweight="bold", ha="center", va="center")
    textsc2+="{}) {} \n".format(txt, string.capwords(ns[i]))

temp2 = subzone3[subzone3["lvl_dc_receiver"]==1]
temp2 = temp2[temp2["lvl_dc_spreader"]!=1]
temp2.plot(ax=axs[1], fc=colors[1], ec="k", lw=1)
textsb2 = ""
idtext = list("pqr")
ns = sorted(temp2["node"].tolist())
xx, yy = get_pos(ns, pos)
for i, txt in enumerate(idtext):
    axs[1].annotate(txt, (xx[i], yy[i]), fontsize=15, fontweight="bold", ha="center", va="center")
    textsb2+="{}) {} \n".format(txt, string.capwords(ns[i]))

i = 0
labs = "ab"
labs2 = ["weekday", "weekend"]
textsa = [textsa1, textsa2]
textsb = [textsb1, textsb2]
textsc = [textsc1, textsc2]
for ax in axs:
    #union_geom.plot(fc="none", ec="k", lw=1.5, ax=ax)
    region.plot(color="none", ec="k", lw=1.5, alpha=1., ax=ax)
    ax.set_xlim([4500,50000])
    ax.set_ylim([25000,50000])
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title("({}) Spatial distribution of super-spreader and super-receiver: {}".format(labs[i], labs2[i]), loc="left", fontsize=18)
    patches1 = []
    patches1.append(mpatches.Patch(color=colors[0], ec="w", label="Spreader & Receiver: \n"+textsa[i], alpha=.7))
    patches1.append(mpatches.Patch(color=colors[2], ec="k", lw=1, label="Spreader: \n"+textsc[i], alpha=1.))
    patches1.append(mpatches.Patch(color=colors[1], ec="k", lw=1, label="Receiver: \n"+textsb[i], alpha=1.))
    leg1 = ax.legend(handles=patches1, ncol=1, fontsize=14, loc="lower left", bbox_to_anchor=(1.005, 0.0))
    #leg1.set_title("Core for", prop={'size':14})
    i+=1



plt.tight_layout()
plt.savefig("../b-calculation/figs/SR_result_map.png", dpi=100, bbox_inches="tight")

# %%
subzone2.columns
# Out:
# Index(['OBJECTID', 'SUBZONE_NO', 'SUBZONE_N', 'SUBZONE_C', 'CA_IND',
#        'PLN_AREA_N', 'PLN_AREA_C', 'REGION_N', 'REGION_C', 'INC_CRC',
#        'FMEL_UPD_D', 'X_ADDR', 'Y_ADDR', 'SHAPE_Leng', 'SHAPE_Area',
#        'geometry', 'node', 'lvl_dc_spreader', 'lvl_hh', 'lvl_pr_spreader',
#        'lvl_dc_receiver', 'lvl_ha', 'lvl_pr_receiver'],
#       dtype='object')

# %%
fig, axs = plt.subplots(2,1, figsize=(18,15))


for ax in axs:
    subzone2.plot(color="grey", edgecolor="k", alpha=0.1, ax=ax)
    #region.plot(color="none", edgecolor="k", alpha=0.8, ax=ax)

colors = ["xkcd:scarlet", "xkcd:light rose", "xkcd:soft purple"]

temp1 = subzone2[subzone2["lvl_dc_spreader"]<=2]
temp1 = temp1[temp1["lvl_dc_receiver"]<=2]
temp1.plot(ax=axs[0], fc=colors[0], ec="w", alpha=.7)
textsa1 = ""
idtext = list("abcdefgh")
temp1b = subzone2[subzone2["lvl_dc_spreader"]<=1]
temp1b = temp1b[temp1b["lvl_dc_receiver"]<=1]
ns = sorted(temp1b["node"].tolist())
xx, yy = get_pos(ns, pos)
for i, txt in enumerate(idtext):
    axs[0].annotate(txt, (xx[i], yy[i]), fontsize=15, ha="center", va="center", fontweight="bold")
    textsa1+="{}) {} \n".format(txt, string.capwords(ns[i]))

temp3 = subzone2[subzone2["lvl_dc_spreader"]<=2]
temp3 = temp3[temp3["lvl_dc_receiver"]>2]
temp3.plot(ax=axs[0], fc=colors[2], ec="k", lw=1)
textsc1 = ""
idtext = list("ijk")
temp3b = subzone2[subzone2["lvl_dc_spreader"]<=1]
temp3b = temp3b[temp3b["lvl_dc_receiver"]>1]
ns = sorted(temp3b["node"].tolist())
xx, yy = get_pos(ns, pos)
for i, txt in enumerate(idtext):
    axs[0].annotate(txt, (xx[i], yy[i]), fontsize=15, ha="center", va="center", fontweight="bold")
    textsc1+="{}) {} \n".format(txt, string.capwords(ns[i]))

temp2 = subzone2[subzone2["lvl_dc_receiver"]<=2]
temp2 = temp2[temp2["lvl_dc_spreader"]>2]
temp2.plot(ax=axs[0], fc=colors[1], ec="k", lw=1)
textsb1 = ""
idtext = list("l")
temp2b = subzone2[subzone2["lvl_dc_receiver"]<=1]
temp2b = temp2b[temp2b["lvl_dc_spreader"]>1]
ns = sorted(temp2b["node"].tolist())
xx, yy = get_pos(ns, pos)
for i, txt in enumerate(idtext):
    axs[0].annotate(txt, (xx[i], yy[i]), fontsize=15, ha="center", va="center", fontweight="bold")
    textsb1+="{}) {} \n".format(txt, string.capwords(ns[i]))



temp1 = subzone3[subzone3["lvl_dc_spreader"]<=2]
temp1 = temp1[temp1["lvl_dc_receiver"]<=2]
temp1.plot(ax=axs[1], fc=colors[0], ec="w", alpha=.7)
textsa2 = ""
idtext = list("abcdefghij")
temp1b = subzone3[subzone3["lvl_dc_spreader"]<=1]
temp1b = temp1b[temp1b["lvl_dc_receiver"]<=1]
ns = sorted(temp1b["node"].tolist())
xx, yy = get_pos(ns, pos)
for i, txt in enumerate(idtext):
    axs[1].annotate(txt, (xx[i], yy[i]), fontsize=15, ha="center", va="center", fontweight="bold")
    textsa2+="{}) {} \n".format(txt, string.capwords(ns[i]))

temp3 = subzone3[subzone3["lvl_dc_spreader"]<=2]
temp3 = temp3[temp3["lvl_dc_receiver"]>2]
temp3.plot(ax=axs[1], fc=colors[2], ec="k", lw=1)
textsc2 = ""
idtext = list("kl")
temp3b = subzone3[subzone3["lvl_dc_spreader"]<=1]
temp3b = temp3b[temp3b["lvl_dc_receiver"]>1]
ns = sorted(temp3b["node"].tolist())
xx, yy = get_pos(ns, pos)
for i, txt in enumerate(idtext):
    axs[1].annotate(txt, (xx[i], yy[i]), fontsize=15, ha="center", va="center", fontweight="bold")
    textsc2+="{}) {} \n".format(txt, string.capwords(ns[i]))

temp2 = subzone3[subzone3["lvl_dc_receiver"]<=2]
temp2 = temp2[temp2["lvl_dc_spreader"]>2]
temp2.plot(ax=axs[1], fc=colors[1], ec="k", lw=1)
textsb2 = ""
idtext = list("mn")
temp2b = subzone3[subzone3["lvl_dc_receiver"]<=1]
temp2b = temp2b[temp2b["lvl_dc_spreader"]>1]
ns = sorted(temp2b["node"].tolist())
xx, yy = get_pos(ns, pos)
for i, txt in enumerate(idtext):
    axs[1].annotate(txt, (xx[i], yy[i]), fontsize=15, ha="center", va="center", fontweight="bold")
    textsb2+="{}) {} \n".format(txt, string.capwords(ns[i]))

i = 0
labs = "ab"
labs2 = ["weekday", "weekend"]
textsa = [textsa1, textsa2]
textsb = [textsb1, textsb2]
textsc = [textsc1, textsc2]
for ax in axs:
    #union_geom.plot(fc="none", ec="k", lw=1.5, ax=ax)
    region.plot(color="none", ec="k", lw=1.5, alpha=1., ax=ax)
    ax.set_xlim([4500,50000])
    ax.set_ylim([25000,50000])
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title("({}) Spatial distribution of super-spreader and super-receiver: {}".format(labs[i], labs2[i]), loc="left", fontsize=18)
    patches1 = []
    patches1.append(mpatches.Patch(color=colors[0], ec="w", label="Spreader & Receiver: \n"+textsa[i], alpha=.7))
    patches1.append(mpatches.Patch(color=colors[2], ec="k", lw=1, label="Spreader: \n"+textsc[i], alpha=1.))
    patches1.append(mpatches.Patch(color=colors[1], ec="k", lw=1, label="Receiver: \n"+textsb[i], alpha=1.))
    leg1 = ax.legend(handles=patches1, ncol=1, fontsize=14, loc="lower left", bbox_to_anchor=(1.005, 0.0))
    #leg1.set_title("Core for", prop={'size':14})
    i+=1



plt.tight_layout()
plt.savefig("figs/SR_result_map_1sd.png", dpi=100, bbox_inches="tight")

# %% [markdown]
# the above map is a little bit confusing, check the weekend-m label Boulevard, it is actually the receiver only for 2SD, and it is both for 1SD-->confusing visualization

# %%
fig, axs = plt.subplots(2,1, figsize=(18,15))


for ax in axs:
    subzone2.plot(color="grey", edgecolor="k", alpha=0.1, ax=ax)
    #region.plot(color="none", edgecolor="k", alpha=0.8, ax=ax)

#colors = ["xkcd:scarlet", "xkcd:light rose", "xkcd:soft purple"]
colors_2 = ["xkcd:scarlet", "xkcd:pale rose"]
border_color = "xkcd:purplish blue"

temp1 = subzone2[subzone2["lvl_dc_spreader"]==1]
temp1.plot(ax=axs[0], fc=colors_2[0], ec="k", lw=1., alpha=.7)
temp1.plot(ax=axs[1], fc="none", ec=border_color, lw=2.5, alpha=.9, zorder=3)
ns = sorted(temp1["node"].tolist())
textsa1 = "Super-Spreader: \n"
idtext = list(string.ascii_lowercase)
id_order = 0
xx, yy = get_pos(ns, pos)
for i, n in enumerate(ns):
    axs[0].annotate(idtext[id_order], (xx[i], yy[i]), fontsize=15, ha="center", va="center", fontweight="bold")
    textsa1+="{}) {} \n".format(idtext[id_order], string.capwords(n))
    id_order+=1
textsa1 = textsa1[:-2]
props = dict(boxstyle='square', facecolor='white', alpha=.9)
axs[0].text(0.01, 0.985, textsa1, transform=axs[0].transAxes, fontsize=14,
        va='top', ha="left", bbox=props)

temp3 = subzone2[subzone2["lvl_dc_spreader"]==2]
temp3.plot(ax=axs[0], fc=colors_2[1], ec="k", lw=.7)


temp1 = subzone2[subzone2["lvl_dc_receiver"]==1]
temp1.plot(ax=axs[1], fc=colors_2[0], ec="k", lw=1., alpha=.7)
temp1.plot(ax=axs[0], fc="none", ec=border_color, lw=2.5, alpha=.9, zorder=3)
ns = sorted(temp1["node"].tolist())
textsb1 = "Super-Receiver: \n"
idtext = list(string.ascii_lowercase)
id_order = 0
xx, yy = get_pos(ns, pos)
for i, n in enumerate(ns):
    axs[1].annotate(idtext[id_order], (xx[i], yy[i]), fontsize=15, ha="center", va="center", fontweight="bold")
    textsb1+="{}) {} \n".format(idtext[id_order], string.capwords(n))
    id_order+=1
textsb1 = textsb1[:-2]
props = dict(boxstyle='square', facecolor='white', alpha=.9)
axs[1].text(0.01, 0.985, textsb1, transform=axs[1].transAxes, fontsize=14,
        va='top', ha="left", bbox=props)

temp3 = subzone2[subzone2["lvl_dc_receiver"]==2]
temp3.plot(ax=axs[1], fc=colors_2[1], ec="k", lw=.7)

i = 0
labs = "ab"
labs2 = ["super-spreader", "super-receiver"]
labs3 = ["Spreader Index", "Receiver Index"]
for ax in axs:
    #union_geom.plot(fc="none", ec="k", lw=1.5, ax=ax)
    region.plot(color="none", ec="k", lw=1.5, alpha=1., ax=ax)
    ax.set_xlim([4500,50000])
    ax.set_ylim([25000,50000])
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title("({}) Spatial distribution of {} on weekday".format(labs[i], labs2[i]), loc="left", fontsize=18)
    ax.annotate("WR", (6500, 38000), ha="right", fontsize=18)
    ax.annotate("NR", (19000, 48500), ha="left", fontsize=18)
    ax.annotate("NER", (34000, 46000), ha="left", fontsize=18)
    ax.annotate("ER", (43000, 32000), ha="left", fontsize=18)
    ax.annotate("CR", (30500, 26500), ha="left", fontsize=18)
    patches1 = []
    patches1.append(mpatches.Patch(color=colors_2[0], ec="k", label="{}$\geq \mu+2\sigma$".format(labs3[i]), alpha=.7))
    patches1.append(mpatches.Patch(color=colors_2[1], ec="k", lw=1, label="{}$\geq \mu+1\sigma$".format(labs3[i]), alpha=.7))
    patches1.append(mpatches.Patch(color="none", ec=border_color, lw=2.5, label="{}$\geq \mu+2\sigma$".format(labs3[1-i]), alpha=.7))
    leg1 = ax.legend(handles=patches1, ncol=1, fontsize=16, loc="lower right")#, bbox_to_anchor=(1.005, 0.0))
    #leg1.set_title(labs3[i], prop={'size':16})
    i+=1

plt.tight_layout()
plt.savefig("../b-calculation/figs/SR_result_map_weekday.png", dpi=100, bbox_inches="tight")

# %%
fig, axs = plt.subplots(2,1, figsize=(18,15))


for ax in axs:
    subzone2.plot(color="grey", edgecolor="k", alpha=0.1, ax=ax)
    #region.plot(color="none", edgecolor="k", alpha=0.8, ax=ax)

#colors = ["xkcd:scarlet", "xkcd:light rose", "xkcd:soft purple"]
colors_2 = ["xkcd:scarlet", "xkcd:pale rose"]
border_color = "xkcd:purplish blue"

temp1 = subzone3[subzone3["lvl_dc_spreader"]==1]
temp1.plot(ax=axs[0], fc=colors_2[0], ec="k", lw=1., alpha=.7)
temp1.plot(ax=axs[1], fc="none", ec=border_color, lw=2.5, alpha=.9, zorder=3)
ns = sorted(temp1["node"].tolist())
textsa1 = "Super-Spreader: \n"
idtext = list(string.ascii_lowercase)
id_order = 0
xx, yy = get_pos(ns, pos)
for i, n in enumerate(ns):
    axs[0].annotate(idtext[id_order], (xx[i], yy[i]), fontsize=15, ha="center", va="center", fontweight="bold")
    textsa1+="{}) {} \n".format(idtext[id_order], string.capwords(n))
    id_order+=1
textsa1 = textsa1[:-2]
props = dict(boxstyle='square', facecolor='white', alpha=.9)
axs[0].text(0.01, 0.985, textsa1, transform=axs[0].transAxes, fontsize=14,
        va='top', ha="left", bbox=props)

temp3 = subzone3[subzone3["lvl_dc_spreader"]==2]
temp3.plot(ax=axs[0], fc=colors_2[1], ec="k", lw=.7)


temp1 = subzone3[subzone3["lvl_dc_receiver"]==1]
temp1.plot(ax=axs[1], fc=colors_2[0], ec="k", lw=1., alpha=.7)
temp1.plot(ax=axs[0], fc="none", ec=border_color, lw=2.5, alpha=.9, zorder=3)
ns = sorted(temp1["node"].tolist())
textsb1 = "Super-Receiver: \n"
idtext = list(string.ascii_lowercase)
id_order = 0
xx, yy = get_pos(ns, pos)
for i, n in enumerate(ns):
    axs[1].annotate(idtext[id_order], (xx[i], yy[i]), fontsize=15, ha="center", va="center", fontweight="bold")
    textsb1+="{}) {} \n".format(idtext[id_order], string.capwords(n))
    id_order+=1
textsb1 = textsb1[:-2]
props = dict(boxstyle='square', facecolor='white', alpha=.9)
axs[1].text(0.01, 0.985, textsb1, transform=axs[1].transAxes, fontsize=14,
        va='top', ha="left", bbox=props)

temp3 = subzone3[subzone3["lvl_dc_receiver"]==2]
temp3.plot(ax=axs[1], fc=colors_2[1], ec="k", lw=.7)

i = 0
labs = "ab"
labs2 = ["super-spreader", "super-receiver"]
labs3 = ["Spreader Index", "Receiver Index"]
for ax in axs:
    #union_geom.plot(fc="none", ec="k", lw=1.5, ax=ax)
    region.plot(color="none", ec="k", lw=1.5, alpha=1., ax=ax)
    ax.set_xlim([4500,50000])
    ax.set_ylim([25000,50000])
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title("({}) Spatial distribution of {} on weekend".format(labs[i], labs2[i]), loc="left", fontsize=18)
    ax.annotate("WR", (6500, 38000), ha="right", fontsize=18)
    ax.annotate("NR", (19000, 48500), ha="left", fontsize=18)
    ax.annotate("NER", (34000, 46000), ha="left", fontsize=18)
    ax.annotate("ER", (43000, 32000), ha="left", fontsize=18)
    ax.annotate("CR", (30500, 26500), ha="left", fontsize=18)
    patches1 = []
    patches1.append(mpatches.Patch(color=colors_2[0], ec="k", label="{}$\geq \mu+2\sigma$".format(labs3[i]), alpha=.7))
    patches1.append(mpatches.Patch(color=colors_2[1], ec="k", lw=1, label="{}$\geq \mu+1\sigma$".format(labs3[i]), alpha=.7))
    patches1.append(mpatches.Patch(color="none", ec=border_color, lw=2.5, label="{}$\geq \mu+2\sigma$".format(labs3[1-i]), alpha=.7))
    leg1 = ax.legend(handles=patches1, ncol=1, fontsize=16, loc="lower right")#, bbox_to_anchor=(1.005, 0.0))
    #leg1.set_title(labs3[i], prop={'size':16})
    i+=1

plt.tight_layout()
plt.savefig("../b-calculation/figs/SR_result_map_weekend.png", dpi=100, bbox_inches="tight")

# %%
sr_weekday_val = pd.read_csv("../b-calculation/results/Super_SR_weekday.csv", index_col=0)
sr_weekend_val = pd.read_csv("../b-calculation/results/Super_SR_weekend.csv", index_col=0)

# %%
sr_weekday_val.head()
# Out:
#                   node  cal_dc_spreader    cal_hh  cal_pr_spreader  \
# ind
# 0        TAMPINES EAST         0.386216  0.386730         0.364033
# 1    SERANGOON CENTRAL         0.273305  0.225932         0.256277
# 2          BEDOK NORTH         0.267416  0.268577         0.250001
# 3         GEYLANG EAST         0.290295  0.279854         0.270455
# 4    TOA PAYOH CENTRAL         0.478774  0.409355         0.466794
#
#      cal_dc_receiver    cal_ha  cal_pr_receiver
# ind
# 0           0.423249  0.423249         0.398408
# 1           0.242025  0.206932         0.228909
# 2           0.242039  0.244966         0.225299
# 3           0.278489  0.273845         0.261286
# 4           0.500865  0.437605         0.486484

# %%
sns.distplot(sr_weekday_val["cal_dc_spreader"])

# %%
sns.distplot(sr_weekday_val["cal_dc_receiver"])

# %%
sns.distplot(sr_weekend_val["cal_dc_spreader"])

# %%
sns.distplot(sr_weekend_val["cal_dc_receiver"])
