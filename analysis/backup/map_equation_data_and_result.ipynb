# %%
import os
import networkx as nx
import pandas as pd
import geopandas as gpd
import json
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data_dir = "../data"
os.listdir(data_dir)
# Out:
# ['bus_stops_wszone.dbf',
#  'bus_stops_wszone.shp',
#  'net_202001_15.net',
#  'OD_bus',
#  'net_202001_05.net',
#  'net_202001_06.net',
#  'origin_destination_train_201912.csv.xz',
#  'train_station_wszone.prj',
#  'origin_destination_train_202001.csv.xz',
#  'train_station_wszone.dbf',
#  'OD_202001_weekend.csv.xz',
#  'net_202001_22.net',
#  'subzone_centroid.csv',
#  'OD_201912_weekday.csv.xz',
#  'origin_destination_bus_201911.csv.xz',
#  'net_202001_19.net',
#  'net_202001_18.net',
#  'train_station_wszone.cpg',
#  'OD_PT',
#  'train_station_wszone.shx',
#  'net_202001_10.net',
#  'OD_201911_weekend.csv.xz',
#  'origin_destination_train_201911.csv.xz',
#  'subzone_centroid_pos.json',
#  'net_202001_21.net',
#  'origin_destination_bus_202001.csv.xz',
#  'OD_201912_weekend.csv.xz',
#  'net_202001_07.net',
#  'origin_destination_bus_201912.csv.xz',
#  'net_202001_23.net',
#  'region-2014',
#  'train_station_wszone.shp',
#  'net_202001_16.net',
#  'OD_train',
#  'bus_stops_wszone.shx',
#  'OD_202001_weekday.csv.xz',
#  'net_202001_20.net',
#  'net_202001_11.net',
#  'bus_stops_wszone.prj',
#  'net_202001_14.net',
#  'subzone-2014',
#  'net_202001_09.net',
#  'net_202001_12.net',
#  'net_202001_08.net',
#  'net_202001_17.net',
#  'net_202001_13.net',
#  'OD_201911_weekday.csv.xz',
#  'bus_stops_wszone.cpg']

# %%
os.listdir("../data")
region = gpd.read_file("../data/region-2014/MP14_REGION_WEB_PL.shp")
region.plot(color="grey", edgecolor="k", alpha=0.1)

# %%
with open(os.path.join("../data", 'subzone_centroid_pos.json'), 'r') as fread:
    pos = json.load(fread)
pos["MARINA SOUTH"]
# Out:
# [31595.83574613999, 29220.18737674884]

# %%
df1 = pd.read_csv(os.path.join(data_dir, 'OD_202001_weekday.csv.xz'))
df1.head()
# Out:
#    ind         origin     destination   hour_05    hour_06    hour_07  \
# 0    0  TAMPINES EAST   TAMPINES EAST  232925.0  1427066.0  2316704.0
# 1    1   SENOKO NORTH  YISHUN CENTRAL    3560.0    14560.0     7020.0
# 2    2       FERNVALE       TRAFALGAR    2680.0    25980.0    19620.0
# 3    3      CHINATOWN            PORT     328.0     3482.0     1452.0
# 4    4       LAKESIDE    TAMAN JURONG     408.0     6854.0    12863.0
#
#      hour_08    hour_09    hour_10    hour_11  ...    hour_14    hour_15  \
# 0  1778107.0  1280905.0  1145098.0  1084878.0  ...  1382846.0  1305843.0
# 1     6380.0     4740.0     4140.0     5820.0  ...    10480.0    17540.0
# 2    24980.0    14180.0    10240.0     8260.0  ...     9060.0    10400.0
# 3     1084.0     1128.0      602.0      534.0  ...      866.0      908.0
# 4    18283.0     7809.0     7015.0     6526.0  ...    12956.0    23380.0
#
#      hour_16    hour_17    hour_18    hour_19    hour_20   hour_21   hour_22  \
# 0  1400255.0  1652029.0  2019632.0  1676532.0  1141877.0  984449.0  739684.0
# 1    22060.0    46820.0    55680.0    23640.0    16620.0    8300.0    4840.0
# 2    11820.0    18520.0    19040.0    12060.0     8360.0    7320.0    6780.0
# 3      747.0      886.0      564.0      754.0      702.0     553.0     573.0
# 4    13425.0    15333.0    15933.0     8697.0     7677.0    4723.0    3355.0
#
#     hour_23
# 0  391909.0
# 1    1940.0
# 2    3160.0
# 3     496.0
# 4    1720.0
#
# [5 rows x 22 columns]

# %%
len(df1)
# Out:
# 31260

# %%
df1b = df1.dropna(subset=["origin", "destination"])

# %%
df1.columns.tolist()
# Out:
# ['ind',
#  'origin',
#  'destination',
#  'hour_05',
#  'hour_06',
#  'hour_07',
#  'hour_08',
#  'hour_09',
#  'hour_10',
#  'hour_11',
#  'hour_12',
#  'hour_13',
#  'hour_14',
#  'hour_15',
#  'hour_16',
#  'hour_17',
#  'hour_18',
#  'hour_19',
#  'hour_20',
#  'hour_21',
#  'hour_22',
#  'hour_23']

# %%
df1[["origin", "destination", "hour_08"]]
# Out:
#                      origin            destination    hour_08
# 0             TAMPINES EAST          TAMPINES EAST  1778107.0
# 1              SENOKO NORTH         YISHUN CENTRAL     6380.0
# 2                  FERNVALE              TRAFALGAR    24980.0
# 3                 CHINATOWN                   PORT     1084.0
# 4                  LAKESIDE           TAMAN JURONG    18283.0
# 5      DEFU INDUSTRIAL PARK           GEYLANG EAST     8360.0
# 6                    YUNNAN                 TUKANG     1680.0
# 7                  LAKESIDE           GEYLANG EAST      853.0
# 8             TEBAN GARDENS             WEST COAST    22400.0
# 9            CLEMENTI WOODS            BEDOK NORTH      360.0
# 10            MARINA CENTRE          MARINA CENTRE     1842.0
# 11             GEYLANG EAST           PEARL'S HILL     2500.0
# 12                  MIDVIEW        WOODLANDS SOUTH    11536.0
# 13               MACPHERSON               ALJUNIED   157775.0
# 14                MARYMOUNT            LEONIE HILL     2680.0
# 15        PASIR RIS CENTRAL             KAKI BUKIT     7782.0
# 16                 ALJUNIED                  KOVAN     5806.0
# 17              FLORA DRIVE                  SIMEI    25880.0
# 18                  MATILDA                MATILDA   403160.0
# 19            PUNGGOL FIELD        PASIR RIS DRIVE     9140.0
# 20             HOUGANG EAST              RIVERVALE    17720.0
# 21     SENGKANG TOWN CENTRE             KAKI BUKIT    51703.0
# 22               CHONG BOON             MACPHERSON     6500.0
# 23               ANAK BUKIT            NORTH COAST     2900.0
# 24         CLEMENTI CENTRAL        MARITIME SQUARE    13340.0
# 25             TAMAN JURONG           JURONG RIVER    35980.0
# 26                BALESTIER              BALESTIER   226660.0
# 27            TAMPINES EAST         CHANGI AIRPORT   342151.0
# 28         BUKIT BATOK WEST               HONG KAH     9400.0
# 29            MANDAI ESTATE           YISHUN SOUTH     2000.0
# ...                     ...                    ...        ...
# 31230             CHENG SAN              BALESTIER        0.0
# 31231                TENGAH              BOAT QUAY        0.0
# 31232           CLARKE QUAY             PENG SIANG        0.0
# 31233         MARINA CENTRE                SENTOSA        0.0
# 31234      BAYFRONT SUBZONE                SENTOSA        0.0
# 31235              SOMERSET                MIDVIEW        0.0
# 31236         MARINA CENTRE            YISHUN EAST        0.0
# 31237           CLARKE QUAY                  DOVER        0.0
# 31238                KRANJI         HONG KAH NORTH        0.0
# 31239         MARINA CENTRE              NORTHLAND        0.0
# 31240             BOULEVARD            NORTH COAST        0.0
# 31241      BAYFRONT SUBZONE         ROBERTSON QUAY        0.0
# 31242           CLARKE QUAY             YUHUA WEST        0.0
# 31243               SENTOSA              TRAFALGAR        0.0
# 31244           CLARKE QUAY                 YUNNAN        0.0
# 31245               KANGKAR                 RIDOUT        0.0
# 31246      BAYFRONT SUBZONE              TRAFALGAR        0.0
# 31247               SENTOSA   SENGKANG TOWN CENTRE        0.0
# 31248           CLARKE QUAY                  FABER        0.0
# 31249           CLARKE QUAY                MIDVIEW        0.0
# 31250             BOAT QUAY  CHOA CHU KANG CENTRAL        0.0
# 31251             BOULEVARD    CHOA CHU KANG NORTH        0.0
# 31252                TENGAH     LORONG 8 TOA PAYOH        0.0
# 31253              SOMERSET    CHOA CHU KANG NORTH        0.0
# 31254                   NaN               HILLVIEW        0.0
# 31255         TEBAN GARDENS          LORONG AH SOO        0.0
# 31256             BOULEVARD             PENG SIANG        0.0
# 31257             KEAT HONG              TURF CLUB        0.0
# 31258               SAUJANA           FARRER COURT        0.0
# 31259               BANGKIT              BENCOOLEN        0.0
#
# [31260 rows x 3 columns]

# %%
dg1_08 = nx.DiGraph()
for s,t,f in zip(df1b["origin"], df1b["destination"], df1b["hour_08"]):
    if s==t: continue
    if f<=0: continue
    dg1_08.add_edge(s,t,weight=f)
dg1_08.number_of_edges()
# Out:
# 26927

# %%
nx.write_pajek(dg1_08, os.path.join(data_dir, "net_202001_08.net"))

# %%
for i in range(5,24):
    dg1 = nx.DiGraph()
    for s,t,f in zip(df1b["origin"], df1b["destination"], df1b["hour_{}".format(str(i).zfill(2))]):
        if s==t: continue
        if f<=0: continue
        dg1.add_edge(s,t,weight=f)
    print(i, dg1.number_of_edges())
    nx.write_pajek(dg1, os.path.join(data_dir, "net_202001_{}.net".format(str(i).zfill(2))))
# Out:
# 5 15717
# 6 24903
# 7 26768
# 8 26927
# 9 26759
# 10 26862
# 11 27104
# 12 27443
# 13 27553
# 14 27576
# 15 27654
# 16 27870
# 17 28251
# 18 28212
# 19 27291
# 20 26494
# 21 26084
# 22 25323
# 23 22600

# %%
for i in range(5,24):
    hrstr = str(i).zfill(2)
    cmd_string = "Infomap --directed --flow-network --two-level -i pajek data/net_202001_{}.net mapequation > mapequation/output_infomap_{}.txt &&".format(hrstr, hrstr)
    print(cmd_string)
# Out:
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_05.net mapequation > mapequation/output_infomap_05.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_06.net mapequation > mapequation/output_infomap_06.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_07.net mapequation > mapequation/output_infomap_07.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_08.net mapequation > mapequation/output_infomap_08.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_09.net mapequation > mapequation/output_infomap_09.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_10.net mapequation > mapequation/output_infomap_10.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_11.net mapequation > mapequation/output_infomap_11.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_12.net mapequation > mapequation/output_infomap_12.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_13.net mapequation > mapequation/output_infomap_13.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_14.net mapequation > mapequation/output_infomap_14.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_15.net mapequation > mapequation/output_infomap_15.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_16.net mapequation > mapequation/output_infomap_16.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_17.net mapequation > mapequation/output_infomap_17.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_18.net mapequation > mapequation/output_infomap_18.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_19.net mapequation > mapequation/output_infomap_19.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_20.net mapequation > mapequation/output_infomap_20.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_21.net mapequation > mapequation/output_infomap_21.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_22.net mapequation > mapequation/output_infomap_22.txt &&
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_23.net mapequation > mapequation/output_infomap_23.txt &&

# %%
fs = os.listdir(os.path.join("../", "mapequation"))
fs = sorted([ f for f in fs if ".tree" in f ])
fs
# Out:
# ['net_202001_05.tree',
#  'net_202001_06.tree',
#  'net_202001_07.tree',
#  'net_202001_08.tree',
#  'net_202001_09.tree',
#  'net_202001_10.tree',
#  'net_202001_11.tree',
#  'net_202001_12.tree',
#  'net_202001_13.tree',
#  'net_202001_14.tree',
#  'net_202001_15.tree',
#  'net_202001_16.tree',
#  'net_202001_17.tree',
#  'net_202001_18.tree',
#  'net_202001_19.tree',
#  'net_202001_20.tree',
#  'net_202001_21.tree',
#  'net_202001_22.tree',
#  'net_202001_23.tree']

# %%
for f in fs:
    print(f)
    res_fp = os.path.join("../", "mapequation", f)
    df_res = pd.read_csv(res_fp, sep=" ", header=None, skiprows=2, names=["clusters", "flow", "node", "ori_index"])
    layers = []
    for c in df_res["clusters"]:
        cs = c.split(":")
        lvl = 1
        la_str = ""
        this_layers = {}
        for la in cs:
            if len(la_str)==0:
                la_str = la
            else:
                la_str = la_str+"_"+la
            this_layers["level_{}".format(lvl)] = la_str
            lvl+=1
        layers.append(this_layers)
    df_lvl = pd.DataFrame.from_dict(layers)
    df_res = df_res.merge(df_lvl, left_index=True, right_index=True)
    #df_res.head()
    df_res.to_csv(os.path.join("../", "mapequation", f.replace(".tree", ".csv")), index_label="ind")
# Out:
# net_202001_05.tree
# net_202001_06.tree
# net_202001_07.tree
# net_202001_08.tree
# net_202001_09.tree
# net_202001_10.tree
# net_202001_11.tree
# net_202001_12.tree
# net_202001_13.tree
# net_202001_14.tree
# net_202001_15.tree
# net_202001_16.tree
# net_202001_17.tree
# net_202001_18.tree
# net_202001_19.tree
# net_202001_20.tree
# net_202001_21.tree
# net_202001_22.tree
# net_202001_23.tree

# %% [markdown]
# Infomap --directed --flow-network --two-level -i pajek data/net_202001_08.net mapequation > SomeFile.txt

# %% [raw]
# Infomap --directed --flow-network --two-level -i pajek --pajek --map data/net_202001_08.net mapequation

# %%
res_fp = os.path.join("../", "mapequation", "net_202001_08.tree")
df_res = pd.read_csv(res_fp, sep=" ", header=None, skiprows=2, names=["clusters", "flow", "node", "ori_index"])
df_res.head()
# Out:
#   clusters      flow             node  ori_index
# 0      1:1  0.014179  MARITIME SQUARE         38
# 1      1:2  0.011295      BUKIT MERAH        194
# 2      1:3  0.011040  CENTRAL SUBZONE        109
# 3      1:4  0.010611            CECIL        218
# 4      1:5  0.010231        BOULEVARD         79

# %%
layers = []
for c in df_res["clusters"]:
    cs = c.split(":")
    lvl = 1
    la_str = ""
    this_layers = {}
    for la in cs:
        if len(la_str)==0:
            la_str = la
        else:
            la_str = la_str+"_"+la
        this_layers["level_{}".format(lvl)] = la_str
        lvl+=1
    layers.append(this_layers)
df_lvl = pd.DataFrame.from_dict(layers)
df_res = df_res.merge(df_lvl, left_index=True, right_index=True)
df_res.head()
# Out:
#   clusters      flow             node  ori_index level_1 level_2
# 0      1:1  0.014179  MARITIME SQUARE         38       1     1_1
# 1      1:2  0.011295      BUKIT MERAH        194       1     1_2
# 2      1:3  0.011040  CENTRAL SUBZONE        109       1     1_3
# 3      1:4  0.010611            CECIL        218       1     1_4
# 4      1:5  0.010231        BOULEVARD         79       1     1_5

# %%
sorted(set(df_res["level_1"].tolist()))
# Out:
# ['1', '10', '11', '12', '13', '2', '3', '4', '5', '6', '7', '8', '9']

# %%
current_palette = sns.color_palette() + sns.color_palette("Set2")
#current_palette = sns.color_palette("Set2")#, 14)
sns.palplot(current_palette)

# %%
xs = []
ys = []
cs = []
fs = []
ws = []

for i in range(len(df_res)):
    row = df_res.iloc[i]
    node = row["node"]
    if pd.isnull(row["node"]):
        print(row)
    layer = int(row["level_1"])
    flow = row["flow"]
    x,y = pos[node]
    clr = current_palette[layer] if layer<len(current_palette) else "grey"
    xs.append(x)
    ys.append(y)
    cs.append(clr)
    fs.append(flow*20000)
    ws.append(layer)
    #break

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.set_aspect("equal")
region.plot(ax=ax, color="grey", edgecolor="k", alpha=0.1)
ax.set_xlim([4500,50000])
ax.set_ylim([25000,50000])
ax.scatter(xs, ys, s=fs, color=cs)

for i, txt in enumerate(ws):
    ax.annotate(txt, (xs[i], ys[i]))
    
plt.tight_layout()

# %%
community = { k:l for k,l in zip(df_res["node"], df_res["level_1"]) }

# %%
dg2 = nx.DiGraph()
for u,v,d in dg1_08.edges(data=True):
    if d["weight"]==0: continue
    cu = community[u]
    cv = community[v]
    if dg2.has_edge(cu,cv):
        dg2[cu][cv]["weight"]+=d["weight"]
    else:
        dg2.add_edge(cu, cv, weight=d["weight"])
dg2.number_of_nodes(), dg2.number_of_edges()
# Out:
# (13, 169)

# %%
"""
def get_bridge(dg, community):
    potential_bridges = []
    for u, v in dg.edges(data=False):
        cu = community[u]
        cv = community[v]
        if cu!=cv:
            potential_bridge.append((u, v))
    return potential_bridges
"""

def get_pairs(cs1, cs2, dg):
    npairs = []
    inter_com = []
    for c1 in cs1:
        for c2 in cs2:
            if nx.has_path(dg, c1, c2):
                npairs.append((c1, c2))
                if dg.has_edge(c1, c2):
                    inter_com.append((c1, c2))
    return npairs, inter_com

def get_shortest_path(dg, npairs, weight=None):
    shortest_paths = []
    for c1, c2 in npairs:
        spath = nx.shortest_path(dg, c1, c2, weight=weight)
        shortest_paths.append(spath)
    return shortest_paths

def get_bridge_ness(inter_com, shortest_paths):
    bcount = { ic:0 for ic in inter_com }
    for spath in shortest_paths:
        for j in range(1, len(spath)):
            i = j - 1
            ed = (spath[i], spath[j])
            if ed in inter_com:
                bcount[ed]+=1
                #break
    df_bridge = pd.DataFrame.from_dict({"in_between": bcount}).reset_index().rename(columns={"level_0": "origin", "level_1": "destination"})
    #df_bridge = df_bridge[df_bridge["in_between"]>0]
    df_bridge = df_bridge.sort_values(by="in_between", ascending=False)
    return df_bridge

# %%
dg1_08b = nx.DiGraph()
for n in dg1_08.nodes():
    dg1_08b.add_node(n)

for u,v,d in dg1_08.edges(data=True):
    if d["weight"]>0:
        dg1_08b.add_edge(u, v, weight=1./d["weight"])

# %%
weight = "weight"

#potential_bridges = get_bridge(dg1b, community)
long_res = pd.DataFrame.from_dict({col:{} for col in ["com_direction", "from_com", "to_com", "origin", "destination", "in_between", "in_between_norm"]})
for com1, com2 in tqdm(dg2.edges()):
    # exist an edge between countries in com1 to countries in com2
    if com1==com2:
        continue
    #print(com1, com2)
    cs1 = df_res[df_res["level_1"]==com1]["node"].tolist()
    cs2 = df_res[df_res["level_1"]==com2]["node"].tolist()
    npairs, inter_com = get_pairs(cs1, cs2, dg1_08b)
    shortest_paths = get_shortest_path(dg1_08b, npairs, weight=weight)
    df_bridge = get_bridge_ness(inter_com, shortest_paths)
    inter_str = "{}-{}".format(com1, com2)
    df_bridge["com_direction"] = inter_str
    df_bridge["from_com"] = com1
    df_bridge["to_com"] = com2
    df_bridge["in_between_norm"] = df_bridge["in_between"] / (len(npairs))#-len(inter_com))
    df_bridge = df_bridge[["com_direction", "from_com", "to_com", "origin", "destination", "in_between", "in_between_norm"]]
    #print(df_bridge.head(10))
    long_res = long_res.append(df_bridge)
    #break
long_res = long_res.reset_index(drop=True)
# Out:
#   0%|          | 0/169 [00:00<?, ?it/s]
#   1%|          | 1/169 [00:00<02:37,  1.07it/s]
#   2%|▏         | 3/169 [00:03<02:44,  1.01it/s]
#   2%|▏         | 4/169 [00:04<03:08,  1.14s/it]
#   3%|▎         | 5/169 [00:09<06:18,  2.31s/it]
#   4%|▎         | 6/169 [00:10<04:49,  1.78s/it]
#   4%|▍         | 7/169 [00:21<12:50,  4.75s/it]
#   5%|▍         | 8/169 [00:23<10:12,  3.81s/it]
#   5%|▌         | 9/169 [00:25<08:48,  3.30s/it]
#   6%|▌         | 10/169 [00:28<08:44,  3.30s/it]
#   7%|▋         | 11/169 [00:36<12:01,  4.57s/it]
#   7%|▋         | 12/169 [00:37<09:33,  3.65s/it]
#   8%|▊         | 13/169 [00:40<08:31,  3.28s/it]
#   8%|▊         | 14/169 [00:41<06:33,  2.54s/it]
#   9%|▉         | 15/169 [00:42<05:18,  2.07s/it]
#   9%|▉         | 16/169 [00:43<04:47,  1.88s/it]
#  10%|█         | 17/169 [00:47<06:34,  2.60s/it]
#  11%|█         | 19/169 [00:48<04:53,  1.96s/it]
#  12%|█▏        | 20/169 [00:50<04:28,  1.80s/it]
#  12%|█▏        | 21/169 [00:55<07:02,  2.85s/it]
#  13%|█▎        | 22/169 [00:57<06:27,  2.63s/it]
#  14%|█▎        | 23/169 [00:58<04:59,  2.05s/it]
#  14%|█▍        | 24/169 [00:58<03:39,  1.52s/it]
#  15%|█▍        | 25/169 [00:59<03:30,  1.46s/it]
#  15%|█▌        | 26/169 [01:00<03:06,  1.31s/it]
#  16%|█▌        | 27/169 [01:08<07:25,  3.14s/it]
#  17%|█▋        | 28/169 [01:09<05:56,  2.53s/it]
#  17%|█▋        | 29/169 [01:11<05:27,  2.34s/it]
#  18%|█▊        | 30/169 [01:14<05:42,  2.46s/it]
#  19%|█▉        | 32/169 [01:20<06:02,  2.65s/it]
#  20%|█▉        | 33/169 [01:21<05:17,  2.33s/it]
#  20%|██        | 34/169 [01:22<04:02,  1.80s/it]
#  21%|██        | 35/169 [01:23<03:43,  1.67s/it]
#  21%|██▏       | 36/169 [01:26<04:20,  1.96s/it]
#  22%|██▏       | 37/169 [01:29<04:44,  2.15s/it]
#  22%|██▏       | 38/169 [01:31<04:38,  2.13s/it]
#  23%|██▎       | 39/169 [01:32<04:17,  1.98s/it]
#  24%|██▎       | 40/169 [01:34<03:49,  1.78s/it]
#  24%|██▍       | 41/169 [01:37<04:33,  2.14s/it]
#  25%|██▌       | 43/169 [01:38<03:42,  1.77s/it]
#  26%|██▌       | 44/169 [01:41<04:18,  2.06s/it]
#  27%|██▋       | 45/169 [01:42<03:32,  1.71s/it]
#  27%|██▋       | 46/169 [01:43<03:11,  1.56s/it]
#  28%|██▊       | 47/169 [01:44<02:52,  1.41s/it]
#  28%|██▊       | 48/169 [01:45<02:15,  1.12s/it]
#  29%|██▉       | 49/169 [01:46<02:24,  1.20s/it]
#  30%|██▉       | 50/169 [01:46<01:54,  1.04it/s]
#  30%|███       | 51/169 [01:47<01:52,  1.05it/s]
#  31%|███       | 52/169 [01:48<01:44,  1.12it/s]
#  31%|███▏      | 53/169 [01:56<05:32,  2.86s/it]
#  33%|███▎      | 55/169 [01:59<04:46,  2.52s/it]
#  33%|███▎      | 56/169 [02:01<04:35,  2.44s/it]
#  34%|███▎      | 57/169 [02:05<05:28,  2.93s/it]
#  34%|███▍      | 58/169 [02:07<04:54,  2.66s/it]
#  35%|███▍      | 59/169 [02:15<07:30,  4.09s/it]
#  36%|███▌      | 60/169 [02:17<06:18,  3.47s/it]
#  36%|███▌      | 61/169 [02:20<06:08,  3.41s/it]
#  37%|███▋      | 62/169 [02:21<04:56,  2.77s/it]
#  37%|███▋      | 63/169 [02:23<04:24,  2.50s/it]
#  38%|███▊      | 64/169 [02:26<04:23,  2.51s/it]
#  38%|███▊      | 65/169 [02:26<03:24,  1.97s/it]
#  39%|███▉      | 66/169 [02:28<02:53,  1.69s/it]
#  40%|████      | 68/169 [02:41<05:23,  3.20s/it]
#  41%|████      | 69/169 [02:57<11:32,  6.92s/it]
#  41%|████▏     | 70/169 [03:04<11:44,  7.12s/it]
#  42%|████▏     | 71/169 [03:08<09:54,  6.06s/it]
#  43%|████▎     | 72/169 [03:14<10:04,  6.23s/it]
#  43%|████▎     | 73/169 [03:17<08:03,  5.04s/it]
#  44%|████▍     | 74/169 [03:24<09:16,  5.86s/it]
#  44%|████▍     | 75/169 [03:29<08:41,  5.54s/it]
#  45%|████▍     | 76/169 [03:31<06:55,  4.47s/it]
#  46%|████▌     | 77/169 [03:33<05:41,  3.71s/it]
#  46%|████▌     | 78/169 [03:38<06:01,  3.97s/it]
#  47%|████▋     | 79/169 [03:39<04:33,  3.04s/it]
#  47%|████▋     | 80/169 [03:39<03:18,  2.23s/it]
#  48%|████▊     | 81/169 [03:41<03:21,  2.29s/it]
#  49%|████▊     | 82/169 [03:48<05:18,  3.67s/it]
#  49%|████▉     | 83/169 [03:51<04:42,  3.29s/it]
#  50%|█████     | 85/169 [03:56<04:20,  3.10s/it]
#  51%|█████     | 86/169 [03:57<03:24,  2.46s/it]
#  51%|█████▏    | 87/169 [03:58<02:52,  2.10s/it]
#  52%|█████▏    | 88/169 [04:00<02:41,  1.99s/it]
#  53%|█████▎    | 89/169 [04:02<02:43,  2.04s/it]
#  53%|█████▎    | 90/169 [04:04<02:42,  2.05s/it]
#  54%|█████▍    | 91/169 [04:05<02:05,  1.61s/it]
#  54%|█████▍    | 92/169 [04:15<05:34,  4.35s/it]
#  56%|█████▌    | 94/169 [04:23<05:09,  4.13s/it]
#  56%|█████▌    | 95/169 [04:42<10:32,  8.54s/it]
#  57%|█████▋    | 96/169 [04:44<08:20,  6.86s/it]
#  57%|█████▋    | 97/169 [04:56<09:57,  8.29s/it]
#  58%|█████▊    | 98/169 [05:04<09:33,  8.08s/it]
#  59%|█████▊    | 99/169 [05:06<07:28,  6.40s/it]
#  59%|█████▉    | 100/169 [05:12<07:00,  6.10s/it]
#  60%|█████▉    | 101/169 [05:18<06:57,  6.14s/it]
#  60%|██████    | 102/169 [05:27<07:43,  6.92s/it]
#  61%|██████    | 103/169 [05:35<07:59,  7.26s/it]
#  62%|██████▏   | 104/169 [05:38<06:43,  6.21s/it]
#  63%|██████▎   | 106/169 [05:43<05:15,  5.01s/it]
#  63%|██████▎   | 107/169 [05:46<04:45,  4.61s/it]
#  64%|██████▍   | 108/169 [06:06<09:18,  9.16s/it]
#  64%|██████▍   | 109/169 [06:11<07:53,  7.90s/it]
#  65%|██████▌   | 110/169 [06:29<10:40, 10.85s/it]
#  66%|██████▌   | 111/169 [06:30<07:44,  8.00s/it]
#  66%|██████▋   | 112/169 [06:34<06:14,  6.58s/it]
#  67%|██████▋   | 113/169 [06:37<05:18,  5.70s/it]
#  67%|██████▋   | 114/169 [06:44<05:27,  5.96s/it]
#  68%|██████▊   | 115/169 [06:51<05:36,  6.24s/it]
#  69%|██████▊   | 116/169 [06:56<05:22,  6.08s/it]
#  69%|██████▉   | 117/169 [07:01<04:51,  5.60s/it]
#  70%|██████▉   | 118/169 [07:04<04:10,  4.91s/it]
#  71%|███████   | 120/169 [07:06<03:03,  3.75s/it]
#  72%|███████▏  | 121/169 [07:07<02:12,  2.77s/it]
#  72%|███████▏  | 122/169 [07:08<01:49,  2.33s/it]
#  73%|███████▎  | 123/169 [07:17<03:19,  4.34s/it]
#  73%|███████▎  | 124/169 [07:18<02:36,  3.48s/it]
#  74%|███████▍  | 125/169 [07:26<03:32,  4.82s/it]
#  75%|███████▍  | 126/169 [07:29<02:53,  4.04s/it]
#  75%|███████▌  | 127/169 [07:31<02:30,  3.58s/it]
#  76%|███████▌  | 128/169 [07:34<02:12,  3.24s/it]
#  76%|███████▋  | 129/169 [07:36<02:03,  3.08s/it]
#  77%|███████▋  | 130/169 [07:38<01:45,  2.69s/it]
#  78%|███████▊  | 131/169 [07:38<01:14,  1.96s/it]
#  78%|███████▊  | 132/169 [07:39<00:59,  1.62s/it]
#  79%|███████▊  | 133/169 [07:40<00:45,  1.26s/it]
#  80%|███████▉  | 135/169 [07:40<00:31,  1.08it/s]
#  80%|████████  | 136/169 [07:41<00:27,  1.19it/s]
#  81%|████████  | 137/169 [07:41<00:24,  1.29it/s]
#  82%|████████▏ | 138/169 [07:43<00:37,  1.22s/it]
#  82%|████████▏ | 139/169 [07:44<00:30,  1.02s/it]
#  83%|████████▎ | 140/169 [07:44<00:23,  1.21it/s]
#  83%|████████▎ | 141/169 [07:45<00:19,  1.43it/s]
#  84%|████████▍ | 142/169 [07:45<00:17,  1.57it/s]
#  85%|████████▍ | 143/169 [07:47<00:26,  1.01s/it]
#  86%|████████▋ | 146/169 [07:48<00:17,  1.29it/s]
#  87%|████████▋ | 147/169 [07:49<00:18,  1.19it/s]
#  88%|████████▊ | 148/169 [07:49<00:15,  1.37it/s]
#  88%|████████▊ | 149/169 [07:51<00:22,  1.11s/it]
#  89%|████████▉ | 150/169 [07:55<00:37,  1.99s/it]
#  89%|████████▉ | 151/169 [07:56<00:30,  1.70s/it]
#  90%|████████▉ | 152/169 [08:01<00:43,  2.56s/it]
#  91%|█████████ | 153/169 [08:03<00:37,  2.32s/it]
#  91%|█████████ | 154/169 [08:03<00:27,  1.83s/it]
#  92%|█████████▏| 155/169 [08:05<00:24,  1.77s/it]
#  92%|█████████▏| 156/169 [08:07<00:22,  1.70s/it]
#  93%|█████████▎| 158/169 [08:07<00:14,  1.31s/it]
#  94%|█████████▍| 159/169 [08:08<00:09,  1.02it/s]
#  95%|█████████▍| 160/169 [08:08<00:07,  1.19it/s]
#  95%|█████████▌| 161/169 [08:11<00:12,  1.57s/it]
#  96%|█████████▌| 162/169 [08:12<00:08,  1.27s/it]
#  96%|█████████▋| 163/169 [08:16<00:12,  2.00s/it]
#  97%|█████████▋| 164/169 [08:17<00:08,  1.79s/it]
#  98%|█████████▊| 165/169 [08:18<00:06,  1.66s/it]
#  98%|█████████▊| 166/169 [08:20<00:04,  1.65s/it]
#  99%|█████████▉| 167/169 [08:21<00:03,  1.59s/it]
#  99%|█████████▉| 168/169 [08:22<00:01,  1.23s/it]
# 100%|██████████| 169/169 [08:23<00:00,  2.98s/it]

# %%
cats = []
for ib in long_res["in_between_norm"]:
    #print(ib)
    cat = ""
    if ib<=0.2: cat = "weak"
    elif ib<=0.4: cat = "medium weak"
    elif ib<=0.6: cat = "medium strong"
    else: cat = "strong"
    cats.append(cat)
long_res["category"] = cats

# %%
long_res2 = long_res[long_res["in_between"]>0]

# %%
fig, ax = plt.subplots()
sns.distplot(long_res2["in_between_norm"], ax=ax, kde=False)#, bins=[i*0.05 for i in range(21)])
#ax.axvline(x=long_res2["in_between_norm"].mean(), ls="--", c="k")
#ax.axvline(x=long_res2["in_between_norm"].mean()+long_res2["in_between_norm"].std(), ls="--", c="k")
ax.axvline(x=0.6, ls="--", c="k")
ax.axvline(x=0.4, ls="--", c="k")
ax.axvline(x=0.2, ls="--", c="k")
#ax.set_xticks([i*0.1 for i in range(11)])

# %%
strong = long_res[long_res["category"]=="strong"]
mstrong = long_res[long_res["category"]=="medium strong"]
mweak = long_res[long_res["category"]=="medium weak"]

lines1 = list(zip(strong["origin"], strong["destination"]))
lines2 = list(zip(mstrong["origin"], mstrong["destination"]))
lines3 = list(zip(mweak["origin"], mweak["destination"]))
lines1
# Out:
# [('GALI BATU', 'JELEBU'),
#  ('BENDEMEER', 'TAMPINES WEST'),
#  ('BALESTIER', 'TYERSALL'),
#  ('HONG KAH', 'JURONG WEST CENTRAL'),
#  ('ANAK BUKIT', 'UPPER THOMSON'),
#  ('CHOA CHU KANG CENTRAL', 'WESTERN WATER CATCHMENT'),
#  ('SENGKANG TOWN CENTRE', 'PUNGGOL FIELD'),
#  ('TAMPINES EAST', 'YISHUN WEST'),
#  ('MATILDA', 'TAMPINES WEST'),
#  ('JURONG WEST CENTRAL', 'HONG KAH'),
#  ('JURONG WEST CENTRAL', 'JOO KOON'),
#  ('WESTERN WATER CATCHMENT', 'CHOA CHU KANG CENTRAL')]

# %%
fig, ax = plt.subplots(figsize=(20,10))
region.plot(fc="lightgrey", ec="w", ax=ax)
ax.set_xlim([4500,50000])
ax.set_ylim([25000,50000])

#ax.scatter(nodes["lon"], nodes["lat"], s=nodes["flow"]*5000, c=[ color_map[g] if g in color_map else "k" for g in nodes["level_1_layer"] ])

ax.scatter(xs, ys, s=fs, color=cs)

for i, txt in enumerate(ws):
    ax.annotate(txt, (xs[i], ys[i]))
    
    
nx.draw_networkx_edges(dg1_08b, edgelist=lines1, pos=pos, width=4, edge_color="r")
nx.draw_networkx_edges(dg1_08b, edgelist=lines2, pos=pos, width=2, edge_color="b")
#nx.draw_networkx_edges(dg1b, edgelist=lines3, pos=pos, width=1, edge_color="k")
ax.set_title("Red: 0.6~1.0; Blue: 0.4~0.6")

plt.tight_layout()
