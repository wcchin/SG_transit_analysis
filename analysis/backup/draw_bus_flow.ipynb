# %%
import os
import pandas as pd
import geopandas as gpd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
with open(os.path.join("../data", 'subzone_centroid_pos.json'), 'r') as fread:
    pos = json.load(fread)
pos["MARINA SOUTH"]
# Out:
# [31595.83574613999, 29220.18737674884]

# %%
os.listdir("../data")
region = gpd.read_file("../data/region-2014/MP14_REGION_WEB_PL.shp")
region.plot(color="grey", edgecolor="k", alpha=0.1)

# %%
data_dir = "../data/OD_bus"

# %%
fs = os.listdir(data_dir)
fs = sorted([ f for f in fs if "weekday" in f ])
fs
# Out:
# ['OD_201912_weekday_00.csv',
#  'OD_201912_weekday_01.csv',
#  'OD_201912_weekday_02.csv',
#  'OD_201912_weekday_03.csv',
#  'OD_201912_weekday_04.csv',
#  'OD_201912_weekday_05.csv',
#  'OD_201912_weekday_06.csv',
#  'OD_201912_weekday_07.csv',
#  'OD_201912_weekday_08.csv',
#  'OD_201912_weekday_09.csv',
#  'OD_201912_weekday_10.csv',
#  'OD_201912_weekday_11.csv',
#  'OD_201912_weekday_12.csv',
#  'OD_201912_weekday_13.csv',
#  'OD_201912_weekday_14.csv',
#  'OD_201912_weekday_15.csv',
#  'OD_201912_weekday_16.csv',
#  'OD_201912_weekday_17.csv',
#  'OD_201912_weekday_18.csv',
#  'OD_201912_weekday_19.csv',
#  'OD_201912_weekday_20.csv',
#  'OD_201912_weekday_21.csv',
#  'OD_201912_weekday_22.csv',
#  'OD_201912_weekday_23.csv']

# %%
f = fs[0]

# %%
fp = os.path.join(data_dir, f)
fp
# Out:
# '../data/OD_bus/OD_201912_weekday_00.csv'

# %%
df = pd.read_csv(fp, index_col=0)
df.head()
# Out:
#             origin         destination  hour  flow
# ind
# 0    TAMPINES EAST           RIVERVALE     0  4047
# 1       MACPHERSON  LORONG 8 TOA PAYOH     0   209
# 2       ANAK BUKIT            HILLVIEW     0  6289
# 3         HILLVIEW         NORTH COAST     0  1748
# 4      CLARKE QUAY      ROBERTSON QUAY     0   798

# %%
df[pd.isnull(df["origin"])]
# Out:
#      origin                destination  hour   flow
# ind
# 2085    NaN               ROCHOR CANAL     0   3401
# 2725    NaN             JURONG GATEWAY     0   2128
# 6055    NaN                  HILLCREST     0    171
# 6503    NaN                        NaN     0  15732
# 7656    NaN                NORTH COAST     0  37430
# 7672    NaN             WOODLANDS WEST     0    190
# 7918    NaN  WOODLANDS REGIONAL CENTRE     0    684
# 8247    NaN             NATURE RESERVE     0     19
# 9318    NaN                  TURF CLUB     0    266

# %%
df[pd.isnull(df["destination"])]
# Out:
#               origin destination  hour    flow
# ind
# 623      NORTH COAST         NaN     0  176909
# 2084    ROCHOR CANAL         NaN     0     437
# 2221       MACKENZIE         NaN     0      57
# 3357          GOMBAK         NaN     0      76
# 4783          KRANJI         NaN     0    1197
# 6503             NaN         NaN     0   15732
# 6702  JURONG GATEWAY         NaN     0      57
# 7574       GALI BATU         NaN     0      76
# 7686   NEWTON CIRCUS         NaN     0      19
# 7750       TECK WHYE         NaN     0      57
# 8541        VICTORIA         NaN     0     133
# 8565      ANAK BUKIT         NaN     0      38
# 9205     MONK'S HILL         NaN     0      19

# %% [markdown]
# checked and these nan are all at JB, see prep_bus_loc.ipynb

# %%
df2 = df.dropna(subset=["origin", "destination"])

# %%
df2[pd.isnull(df2["destination"])]
# Out:
# Empty DataFrame
# Columns: [origin, destination, hour, flow]
# Index: []

# %%
recs = []
for i in range(len(df2)):
    row = df2.iloc[i]
    o = row["origin"]
    d = row['destination']
    f = row['flow']
    recs.append((o,d,{"weight":f}))

# %%
dg = nx.DiGraph()
dg.add_edges_from(recs)
dg.number_of_nodes(), dg.number_of_edges()
# Out:
# (296, 9347)

# %%
print(dg.nodes())
# Out:
# ['TAMPINES EAST', 'RIVERVALE', 'MACPHERSON', 'LORONG 8 TOA PAYOH', 'ANAK BUKIT', 'HILLVIEW', 'NORTH COAST', 'CLARKE QUAY', 'ROBERTSON QUAY', 'ROCHOR CANAL', 'ALJUNIED', 'SINGAPORE GENERAL HOSPITAL', 'DOVER', 'HOUGANG EAST', 'SELETAR HILLS', 'YUHUA WEST', 'WOODLANDS WEST', 'KEMBANGAN', 'YUNNAN', 'BOON LAY PLACE', 'SIMEI', 'KAKI BUKIT', 'TOA PAYOH CENTRAL', 'BRADDELL', 'PASIR RIS DRIVE', 'BEDOK NORTH', 'TEBAN GARDENS', 'CLEMENTI CENTRAL', 'YISHUN WEST', 'CITY HALL', 'CHINATOWN', 'BENDEMEER', 'SERANGOON GARDEN', 'ANCHORVALE', 'BISHAN EAST', 'LAVENDER', 'YUHUA EAST', 'CENTRAL WATER CATCHMENT', 'BUKIT BATOK CENTRAL', 'SENJA', 'TRAFALGAR', 'HOUGANG CENTRAL', 'TOH GUAN', 'MANDAI EAST', 'CHONG BOON', 'BALESTIER', 'TAGORE', 'FARRER PARK', 'RIDOUT', 'FARRER COURT', 'ONE TREE HILL', 'MEI CHIN', 'TECK WHYE', 'BUKIT BATOK WEST', 'HONG KAH NORTH', 'MOUNTBATTEN', 'LORONG AH SOO', 'GEYLANG EAST', 'BEDOK RESERVOIR', 'KOVAN', 'YISHUN CENTRAL', 'BOON KENG', 'KATONG', 'HOLLAND ROAD', 'PASIR PANJANG 1', 'TAMAN JURONG', 'DUNEARN', 'LEEDON PARK', 'LOYANG EAST', 'MARYMOUNT', 'SOMERSET', 'NATURE RESERVE', 'LITTLE INDIA', 'BOAT QUAY', 'COMMONWEALTH', 'CHANGI AIRPORT', "PEOPLE'S PARK", 'DHOBY GHAUT', 'WESTERN WATER CATCHMENT', 'ADMIRALTY', 'SEMBAWANG SPRINGS', 'HENDERSON HILL', 'SEMBAWANG CENTRAL', 'MATILDA', 'KHATIB', 'KAMPONG TIONG BAHRU', 'QUEENSWAY', 'MARINA CENTRE', 'TIONG BAHRU', 'ANG MO KIO TOWN CENTRE', 'PATERSON', 'MARITIME SQUARE', 'SENGKANG TOWN CENTRE', 'KALLANG BAHRU', 'BEDOK SOUTH', 'BUGIS', 'PASIR RIS CENTRAL', 'LORONG CHUAN', 'FRANKEL', 'JOO SENG', 'TAMPINES WEST', 'JURONG WEST CENTRAL', 'NORTHLAND', 'SEMBAWANG EAST', 'UPPER THOMSON', 'SENOKO NORTH', 'NASSIM', 'CORONATION ROAD', 'SIGLAP', 'MARINE PARADE', 'HOUGANG WEST', 'YEW TEE', 'MAXWELL', 'TURF CLUB', 'COMPASSVALE', 'CHENG SAN', 'JELEBU', 'THE WHARVES', 'MOULMEIN', 'MALCOLM', 'MARGARET DRIVE', 'HONG KAH', 'GOMBAK', 'HILLCREST', 'SENNETT', 'SERANGOON NORTH', 'TANGLIN HALT', 'SHANGRI-LA', 'BRAS BASAH', 'KAMPONG UBI', 'FAJAR', 'BOULEVARD', 'SUNGEI ROAD', 'ALEXANDRA HILL', 'TOA PAYOH WEST', 'TANJONG RHU', 'YIO CHU KANG NORTH', 'FERNVALE', 'YISHUN SOUTH', 'SELEGIE', 'BANGKIT', 'POTONG PASIR', 'VICTORIA', 'YIO CHU KANG', 'SERANGOON CENTRAL', 'SEMBAWANG NORTH', 'BUKIT MERAH', 'LAKESIDE', 'GUILIN', 'INSTITUTION HILL', 'CHOA CHU KANG NORTH', 'DAIRY FARM', 'GEYLANG BAHRU', 'NEWTON CIRCUS', 'BUKIT BATOK SOUTH', 'REDHILL', 'TELOK BLANGAH RISE', 'TIONG BAHRU STATION', 'CRAWFORD', 'YIO CHU KANG WEST', 'KIAN TECK', 'KEBUN BAHRU', 'PASIR RIS WEST', 'CHOA CHU KANG CENTRAL', 'KRANJI', 'YIO CHU KANG EAST', 'BIDADARI', 'CHANGI WEST', 'RAFFLES PLACE', 'BAYFRONT SUBZONE', 'CENTRAL SUBZONE', 'EVERTON PARK', "PEARL'S HILL", 'ANSON', 'KAMPONG JAVA', 'JURONG GATEWAY', 'CLEMENTI WEST', 'PASIR RIS PARK', 'JURONG RIVER', 'CHANGI POINT', 'WOODLANDS EAST', 'MARINA SOUTH', 'STRAITS VIEW', 'KALLANG WAY', 'SPRINGLEAF', 'WOODLANDS REGIONAL CENTRE', 'PUNGGOL FIELD', 'PORT', 'PAYA LEBAR EAST', 'PASIR RIS WAFER FAB PARK', 'UPPER PAYA LEBAR', 'WATERWAY EAST', 'CHINA SQUARE', 'BUKIT BATOK EAST', 'CLEMENTI WOODS', 'NEE SOON', 'KAMPONG BUGIS', 'SENTOSA', 'CITY TERMINALS', 'WOODLANDS SOUTH', 'WOODGROVE', 'SENOKO WEST', 'MANDAI WEST', 'ONE NORTH', 'FABER', 'SWISS CLUB', 'TENGAH', 'CLIFFORD PIER', 'WOODLEIGH', 'TAI SENG', 'LEONIE HILL', 'MOUNT PLEASANT', 'KENT RIDGE', 'KAMPONG GLAM', 'BOON TECK', 'KANGKAR', 'KIM KEAT', 'BUKIT HO SWEE', 'SAUJANA', 'PENJURU CRESCENT', 'JURONG PORT', 'MIDVIEW', 'CECIL', 'FLORA DRIVE', 'SAFTI', 'TELOK BLANGAH DRIVE', 'TOWNSVILLE', 'CHATSWORTH', 'FORT CANNING', 'BRICKWORKS', 'BENCOOLEN', 'MACKENZIE', 'MANDAI ESTATE', 'XILIN', 'YISHUN EAST', 'KEAT HONG', 'ULU PANDAN', 'GALI BATU', 'SINGAPORE POLYTECHNIC', "NATIONAL UNIVERSITY OF S'PORE", 'SELETAR', 'SENOKO SOUTH', 'PENG SIANG', 'DEPOT ROAD', 'PASIR PANJANG 2', 'NORTHSHORE', 'ALEXANDRA NORTH', 'WENYA', 'TOH TUCK', 'CLEMENTI NORTH', 'HOLLAND DRIVE', 'GREENWOOD PARK', 'PEI CHUN', 'TYERSALL', 'WEST COAST', 'LIU FANG', 'PAYA LEBAR NORTH', 'LOYANG WEST', ' ...

# %%
weights = []
for u,v,d in dg.edges(data=True):
    if d["weight"]>5000:
        weights.append(d["weight"])
sns.distplot(weights, kde=False)

# %%
weights = []
for u,v,d in dg.edges(data=True):
    weights.append((d["weight"], u, v))
weights = sorted(weights, reverse=True)

# %%
print(list(pos.keys()))
# Out:
# ['MARINA SOUTH', "PEARL'S HILL", 'BOAT QUAY', 'HENDERSON HILL', 'REDHILL', 'ALEXANDRA HILL', 'BUKIT HO SWEE', 'CLARKE QUAY', 'PASIR PANJANG 1', 'QUEENSWAY', 'KENT RIDGE', 'ALEXANDRA NORTH', 'MARINA EAST', 'INSTITUTION HILL', 'ROBERTSON QUAY', 'JURONG ISLAND AND BUKOM', 'SUDONG', 'SEMAKAU', 'SOUTHERN GROUP', 'SENTOSA', 'CITY TERMINALS', 'ANSON', 'STRAITS VIEW', 'MARITIME SQUARE', 'TELOK BLANGAH WAY', 'MAXWELL', 'CECIL', 'KAMPONG TIONG BAHRU', 'TELOK BLANGAH DRIVE', 'PASIR PANJANG 2', 'CENTRAL SUBZONE', 'SINGAPORE GENERAL HOSPITAL', 'DEPOT ROAD', "PEOPLE'S PARK", 'BUKIT MERAH', 'CHINATOWN', 'PHILLIP', 'RAFFLES PLACE', 'CHINA SQUARE', 'TIONG BAHRU', 'BAYFRONT SUBZONE', 'TIONG BAHRU STATION', 'CLIFFORD PIER', 'MARINA EAST (MP)', 'MARINA CENTRE', 'BRAS BASAH', 'OXLEY', 'CITY HALL', 'MEI CHIN', 'EAST COAST', "NATIONAL UNIVERSITY OF S'PORE", 'ONE TREE HILL', 'SOMERSET', 'BENCOOLEN', 'LEONIE HILL', 'PORT', 'DHOBY GHAUT', 'BUGIS', 'VICTORIA', 'PATERSON', 'TELOK BLANGAH RISE', 'TANJONG PAGAR', 'EVERTON PARK', 'TANGLIN HALT', 'MACKENZIE', 'SUNGEI ROAD', 'ONE NORTH', 'TANJONG RHU', 'MOUNTBATTEN', 'COMMONWEALTH', 'DOVER', 'RIDOUT', 'CAIRNHILL', 'CLEMENTI WEST', 'TUAS VIEW EXTENSION', "MONK'S HILL", 'SIGLAP', 'CLEMENTI WOODS', 'PIONEER SECTOR', 'PENJURU CRESCENT', 'ORANGE GROVE', 'KAMPONG BUGIS', 'BOULEVARD', 'ISTANA NEGARA', 'LITTLE INDIA', 'GUL BASIN', 'FORT CANNING', 'FARRER COURT', 'TUAS VIEW', 'NASSIM', 'WEST COAST', 'BAYSHORE', 'BENOI SECTOR', 'GUL CIRCLE', 'CHATSWORTH', 'KAMPONG GLAM', 'SELEGIE', 'MOUNT EMILY', 'ROCHOR CANAL', 'CRAWFORD', 'MARGARET DRIVE', 'TANGLIN', 'MARINE PARADE', 'JURONG RIVER', 'GEYLANG BAHRU', 'FABER', 'MALCOLM', 'BEDOK SOUTH', 'BENDEMEER', 'BALESTIER', 'TUAS BAY', 'JOO KOON', 'KALLANG WAY', 'INTERNATIONAL BUSINESS PARK', 'TUKANG', 'CORONATION ROAD', 'KEMBANGAN', 'KATONG', 'HOLLAND DRIVE', 'FARRER PARK', 'NEWTON CIRCUS', 'JURONG PORT', 'SAMULUN', 'SHIPYARD', 'GHIM MOH', 'LAVENDER', 'GOODWOOD PARK', 'PANDAN', 'SINGAPORE POLYTECHNIC', 'CLEMENTI CENTRAL', 'KAMPONG JAVA', 'BOON KENG', 'KALLANG BAHRU', 'ULU PANDAN', 'JURONG GATEWAY', 'HOLLAND ROAD', 'KAMPONG UBI', 'SENNETT', 'POTONG PASIR', 'TUAS NORTH', 'PEI CHUN', 'BOON TECK', 'KIAN TECK', 'SAFTI', 'WOODLEIGH', 'TAMAN JURONG', 'LAKESIDE', 'TOA PAYOH WEST', 'KAKI BUKIT', 'YUHUA EAST', 'BUKIT BATOK SOUTH', 'JURONG WEST CENTRAL', 'BEDOK RESERVOIR', 'TOH TUCK', 'MOUNT PLEASANT', 'HILLCREST', 'JOO SENG', 'CHIN BEE', 'LORONG 8 TOA PAYOH', 'TOH GUAN', 'BRADDELL', 'BIDADARI', 'ALJUNIED', 'TYERSALL', 'MOULMEIN', 'LIU FANG', 'FRANKEL', 'CLEMENTI NORTH', 'LEEDON PARK', 'GEYLANG EAST', 'TEBAN GARDENS', 'BOON LAY PLACE', 'BUKIT BATOK EAST', 'BUKIT BATOK WEST', 'BUKIT BATOK CENTRAL', 'UPPER PAYA LEBAR', 'HONG KAH', 'TUAS PROMENADE', 'AIRPORT ROAD', 'SERANGOON CENTRAL', 'BISHAN EAST', 'TAMPINES WEST', 'BRICKWORKS', 'DEFU INDUSTRIAL PARK', 'GUILIN', 'MARYMOUNT', 'WENYA', 'NATURE RESERVE', 'TAMPINES EAST', 'TAI SENG', 'TENGEH', 'YUHUA WEST', 'YUNNAN', 'LORONG CHUAN', 'DUNEARN', 'SUNSET WAY', 'MACPHERSON', 'KIM KEAT', 'BEDOK NORTH', 'TOA PAYOH CENTRAL', 'PAYA LEBAR NORTH', 'HOUGANG EAST', 'LORONG HALUS', 'KANGKAR', 'SEMBAWANG HILLS', 'JELEBU', 'KEAT HONG', 'HOUGANG WEST', 'PAYA LEBAR WEST', 'BANGKIT', 'ANAK BUKIT', 'SWISS CLUB', 'XILIN', 'SIMEI', 'PENG SIANG', 'PASIR RIS WEST', 'YIO CHU KANG WEST', 'TRAFALGAR', 'TECK WHYE', 'CHOA CHU KANG CENTRAL', 'CHANGI WEST', 'FAJAR', 'SENJA', 'SAUJANA', 'SELETAR HILLS', 'COMPASSVALE', 'YIO CHU KANG EAST', 'YIO CHU KANG', 'LOYANG WEST', 'TAGORE', 'LORONG AH SOO', 'FLORA DRIVE', 'HILLVIEW', 'CHANGI BAY', 'PAYA LEBAR EAST', 'UPPER THOMSON', 'HONG KAH NORTH', 'TOWNSVILLE', 'KOVAN', 'CHONG BOON', 'SHANGRI-LA', 'SERANGOON GARDEN', 'HOUGANG CENTRAL', 'LOYANG EAST', 'DAIRY FARM', 'PASIR RIS DRIVE', 'TAMPINES NORTH', 'CHENG SAN', 'ANG MO KIO TOWN CENTRE', 'KEBUN BAHRU', 'SERANGOON NORTH IND ESTATE', 'TENGAH', 'SERANGOON NORTH', 'PASIR RIS CENTRAL', 'GOMBAK', 'PLAB', 'KRANJI', 'PASIR RIS PARK', 'CHOA CHU KANG NORTH', 'RIVERVALE', 'SENGKANG WEST', 'FERNV ...

# %%
def draw_fig(dg, hr):
    weights = []
    for u,v,d in dg.edges(data=True):
        weights.append((d["weight"], u, v))
    weights = sorted(weights, reverse=True)
    
    fig, ax = plt.subplots(figsize=(20,10))
    nx.draw_networkx_nodes(dg, node_size=10, pos=pos, ax=ax)
    
    threshold = 3000
    if len(weights)>threshold:
        break_val = int(float(threshold)/3.)
    else:
        break_val = int(float(len(weights))/3.)
    edges1 = [ (u,v) for w,u,v in weights[0:break_val] ]
    edges2 = [ (u,v) for w,u,v in weights[break_val:break_val*2] ]
    edges3 = [ (u,v) for w,u,v in weights[break_val*2:break_val*3] ]
    nx.draw_networkx_edges(dg, edgelist=edges1, width=1., edge_color="red", pos=pos, ax=ax)
    nx.draw_networkx_edges(dg, edgelist=edges2, width=0.5, edge_color="blue", pos=pos, ax=ax)
    nx.draw_networkx_edges(dg, edgelist=edges3, width=0.1, edge_color="green", pos=pos, ax=ax)
    
    ax.set_aspect("equal")
    region.plot(ax=ax, color="grey", edgecolor="k", alpha=0.1)
    ax.set_xlim([5000,50000])
    ax.set_ylim([25000,50000])
    #ax.set_xticks([])
    #ax.set_yticks([])
    ax.set_title("bus flow, weekday, hour: {}, count edges: {}".format(hr, str(len(weights))))
    plt.tight_layout()
    figout = os.path.join("bus_flow_fig", "fig_bus_weekday_{}.png".format(hr))
    plt.savefig(figout, dpi=300, bbox_inches="tight")
    plt.close()

# %%
for f in fs[0:6]:
    print(f)
    hr = f[-6:-4]
    fp = os.path.join(data_dir, f)
    df = pd.read_csv(fp, index_col=0)
    df = df.dropna(subset=["origin", "destination"])
    recs = []
    for i in range(len(df)):
        row = df.iloc[i]
        o = row["origin"]
        d = row['destination']
        f = row['flow']
        recs.append((o,d,{"weight":f}))
    dg = nx.DiGraph()
    dg.add_nodes_from(list(pos.keys()))
    dg.add_edges_from(recs)
    draw_fig(dg, hr)
    print(hr, dg.number_of_nodes(), dg.number_of_edges())
    break
print("done")
# Out:
# OD_201912_weekday_00.csv
# 00 323 9347
# done
